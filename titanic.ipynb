# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from subprocess import check_output
print(check_output(["ls", "./data"]).decode("utf8"))
# Out:
# gender_submission.csv
# test.csv
# train.csv

# %%
train_df = pd.read_csv("./data/train.csv")
test_df = pd.read_csv("./data/test.csv")

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x='Survived',data = train_df)

# %%
train_df.Survived.sum()/train_df.Survived.count()
# Out:
# 0.3838383838383838

# %%
test_df['Survived'] = 0
test_df[['PassengerId', 'Survived']].to_csv('no_survivors.csv', index=False)

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0

# %%
test_df[["Name","Sex"]]
# Out:
#                                                   Name     Sex
# 0                                     Kelly, Mr. James    male
# 1                     Wilkes, Mrs. James (Ellen Needs)  female
# 2                            Myles, Mr. Thomas Francis    male
# 3                                     Wirz, Mr. Albert    male
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                           Svensson, Mr. Johan Cervin    male
# 6                                 Connolly, Miss. Kate  female
# 7                         Caldwell, Mr. Albert Francis    male
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                              Davies, Mr. John Samuel    male
# 10                                    Ilieff, Mr. Ylio    male
# 11                          Jones, Mr. Charles Cresson    male
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                                Howard, Mr. Benjamin    male
# ...

# %%
train_df.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.factorplot(x='Sex', col='Survived', kind='count', data=train_df);
# Out:
# /home/ai2/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
print("% of women survived: " , train_df[train_df.Sex == 'female'].Survived.sum()/train_df[train_df.Sex == 'female'].Survived.count())
print("% of men survived:   " , train_df[train_df.Sex == 'male'].Survived.sum()/train_df[train_df.Sex == 'male'].Survived.count())
# Out:
# % of women survived:  0.7420382165605095
# % of men survived:    0.18890814558058924

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
train_df['Survived'][train_df['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
train_df['Survived'][train_df['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')

plt.show()

# %%
test_df['Survived'] = test_df.Sex == 'female'
test_df['Survived'] = test_df.Survived.apply(lambda x: int(x))
test_df[['PassengerId', 'Survived']].to_csv('women_survive.csv', index=False)

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
"""Passenger Class : Survival rate decreases with Pclass
"""
# Out:
# 'Passenger Class : Survival rate decreases with Pclass\n'

# %%
pd.crosstab(train_df.Pclass, train_df.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow0_col0 {
#             background-color:  #ffff00;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow0_col1 {
#             background-color:  #ffce00;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow0_col2 {
#             background-color:  #fff400;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow1_col0 {
#             background-color:  #fff600;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow1_col1 {
#             background-color:  #ffff00;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow1_col2 {
#             background-color:  #ffff00;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow2_col0 {
#             background-color:  #ff6000;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow2_col1 {
#             background-color:  #ffdf00;
#         }    #T_296f3794_8cd3_11e9_9954_8cec4b706d3erow2_col2 {
#             background-color:  #ff9000;
# ...

# %%
train_df.groupby(['Survived','Embarked'])['Survived'].count()
# Out:
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# Name: Survived, dtype: int64

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def per(cls):
    a = train_df['Survived'][train_df.Pclass == cls]
    rate = a.sum()/a.count()
    return rate

# %%
print("Survival rate for Pclass = 1 :",per(1))
print("Survival rate for Pclass = 2 :",per(2))
print("Survival rate for Pclass = 3 :",per(3))
# Out:
# Survival rate for Pclass = 1 : 0.6296296296296297
# Survival rate for Pclass = 2 : 0.47282608695652173
# Survival rate for Pclass = 3 : 0.24236252545824846

# %%
sns.factorplot(x='Pclass', col='Survived', kind='count', data=train_df);
# Out:
# /home/ai2/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('Pclass','Survived', kind='point', data=train_df);
# Out:
# /home/ai2/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
"""Passenger Class and Sex :

Almost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 died
"""
# Out:
# 'Passenger Class and Sex :\n\nAlmost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 died\n'

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab([train_df.Sex, train_df.Survived], train_df.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow0_col0 {
#             background-color:  #ffff00;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow0_col1 {
#             background-color:  #ffff00;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow0_col2 {
#             background-color:  #fff100;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow0_col3 {
#             background-color:  #ffff00;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow1_col0 {
#             background-color:  #ff9600;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow1_col1 {
#             background-color:  #ffa300;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow1_col2 {
#             background-color:  #fff100;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow1_col3 {
#             background-color:  #ffcf00;
#         }    #T_2ec43bd6_8cd3_11e9_9954_8cec4b706d3erow2_col0 {
#             background-color:  #ffa700;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex', kind='point', data=train_df);
# Out:
# /home/ai2/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
"""
Passenger Class and Sex :

Almost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 die
"""
# Out:
# '\nPassenger Class and Sex :\n\nAlmost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 die\n'

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab([train_df.Sex, train_df.Survived], train_df.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow0_col0 {
#             background-color:  #ffff00;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow0_col1 {
#             background-color:  #ffff00;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow0_col2 {
#             background-color:  #fff100;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow0_col3 {
#             background-color:  #ffff00;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow1_col0 {
#             background-color:  #ff9600;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow1_col1 {
#             background-color:  #ffa300;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow1_col2 {
#             background-color:  #fff100;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow1_col3 {
#             background-color:  #ffcf00;
#         }    #T_378b9b1e_8cd4_11e9_9954_8cec4b706d3erow2_col0 {
#             background-color:  #ffa700;
# ...

# %%
sns.catplot('Pclass','Survived',hue='Sex', kind='point', data=train_df);

# %%
"""Embarked : Survival rate lowest for S and highest for C

"""
# Out:
# 'Embarked : Survival rate lowest for S and highest for C\n\n'

# %%
pd.crosstab([train_df.Embarked, train_df.Survived], train_df.Sex, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow0_col0 {
#             background-color:  #ffff00;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow0_col1 {
#             background-color:  #ffe300;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow0_col2 {
#             background-color:  #fff200;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow1_col0 {
#             background-color:  #ffd100;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow1_col1 {
#             background-color:  #fff400;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow1_col2 {
#             background-color:  #ffed00;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow2_col0 {
#             background-color:  #ffff00;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow2_col1 {
#             background-color:  #fff000;
#         }    #T_b698a8b4_8cd6_11e9_9954_8cec4b706d3erow2_col2 {
#             background-color:  #fffa00;
# ...

# %%
sns.catplot('Survived','Sex',col = 'Embarked', kind='point', data=train_df);

# %%
pd.crosstab([train_df.Survived], [train_df.Sex, train_df.Pclass, train_df.Embarked], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col0 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col1 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col2 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col3 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col4 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col5 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col6 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col7 {
#             background-color:  #ffff00;
#         }    #T_da9690a4_8cd7_11e9_9954_8cec4b706d3erow0_col8 {
#             background-color:  #ff9900;
# ...

# %%
"""
third model : based on PClass, Sex and Embarked , submission : 0.779 accuracy


"""
# Out:
# '\nthird model : based on PClass, Sex and Embarked , submission : 0.779 accuracy\n\n\n'

# %%
# model 3
test_df['Survived'] = 0
# all women survived
test_df.loc[ (test_df.Sex == 'female'), 'Survived'] = 1
# except for those in Pclass 3 and embarked in S
test_df.loc[ (test_df.Sex == 'female') & (test_df.Pclass == 3) & (df_test.Embarked == 'S') , 'Survived'] = 0
df_test[['PassengerId', 'Survived']].to_csv('embarked_pclass_sex.csv', index=False)

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1
